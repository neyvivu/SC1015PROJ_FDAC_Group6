# %% [markdown]
# # **Dataset:** [Multi-Class Prediction of Obesity Risk Dataset](https://www.kaggle.com/competitions/playground-series-s4e2)
#
# ## **Questions to answer:**
# - (Classification) How important is each variable in predicting an individual’s risk of having cardiovascular disease?
# - (Classification) Is there a way to categorise individuals' level of obesity based on information about health and daily habits?

# %% [markdown]
# ## **IMPORT NECESSARY LIBRARIES**

# %%
import numpy as np
import pandas as pd
import seaborn as sb

from pathlib import Path

# %% [markdown]
# ## **IMPORT DATA**

# %%
# Load the dataset
train_set = "train.csv"
data = pd.read_csv(train_set)
data
# Out:
#           id  Gender        Age    Height      Weight  \
# 0          0    Male  24.443011  1.699998   81.669950
# 1          1  Female  18.000000  1.560000   57.000000
# 2          2  Female  18.000000  1.711460   50.165754
# 3          3  Female  20.952737  1.710730  131.274851
# 4          4    Male  31.641081  1.914186   93.798055
# ...      ...     ...        ...       ...         ...
# 20753  20753    Male  25.137087  1.766626  114.187096
# 20754  20754    Male  18.000000  1.710000   50.000000
# 20755  20755    Male  20.101026  1.819557  105.580491
# 20756  20756    Male  33.852953  1.700000   83.520113
# 20757  20757    Male  26.680376  1.816547  118.134898
#
#       family_history_with_overweight FAVC      FCVC       NCP        CAEC  \
# 0                                yes  yes  2.000000  2.983297   Sometimes
# 1                                yes  yes  2.000000  3.000000  Frequently
# 2                                yes  yes  1.880534  1.411685   Sometimes
# 3                                yes  yes  3.000000  3.000000   Sometimes
# 4                                yes  yes  2.679664  1.971472   Sometimes
# ...                              ...  ...       ...       ...         ...
# 20753                            yes  yes  2.919584  3.000000   Sometimes
# 20754                             no  yes  3.000000  4.000000  Frequently
# 20755                            yes  yes  2.407817  3.000000   Sometimes
# 20756                            yes  yes  2.671238  1.971472   Sometimes
# 20757                            yes  yes  3.000000  3.000000   Sometimes
#
#       SMOKE      CH2O SCC       FAF       TUE       CALC  \
# 0        no  2.763573  no  0.000000  0.976473  Sometimes
# 1        no  2.000000  no  1.000000  1.000000         no
# 2        no  1.910378  no  0.866045  1.673584         no
# 3        no  1.674061  no  1.467863  0.780199  Sometimes
# 4        no  1.979848  no  1.967973  0.931721  Sometimes
# ...     ...       ...  ..       ...       ...        ...
# 20753    no  2.151809  no  1.330519  0.196680  Sometimes
# 20754    no  1.000000  no  2.000000  1.000000  Sometimes
# 20755    no  2.000000  no  1.158040  1.198439         no
# 20756    no  2.144838  no  0.000000  0.973834         no
# 20757    no  2.003563  no  0.684487  0.713823  Sometimes
#
#                       MTRANS           NObeyesdad
# 0      Public_Transportation  Overweight_Level_II
# 1                 Automobile        Normal_Weight
# 2      Public_Transportation  Insufficient_Weight
# 3      Public_Transportation     Obesity_Type_III
# 4      Public_Transportation  Overweight_Level_II
# ...                      ...                  ...
# 20753  Public_Transportation      Obesity_Type_II
# 20754  Public_Transportation  Insufficient_Weight
# 20755  Public_Transportation      Obesity_Type_II
# 20756             Automobile  Overweight_Level_II
# 20757  Public_Transportation      Obesity_Type_II
#
# [20758 rows x 18 columns]

# %% [markdown]
# *Quick overview*

# %%
display('Data set:', data.head())
# Out:
# 'Data set:'
#    id  Gender        Age    Height      Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998   81.669950                            yes
# 1   1  Female  18.000000  1.560000   57.000000                            yes
# 2   2  Female  18.000000  1.711460   50.165754                            yes
# 3   3  Female  20.952737  1.710730  131.274851                            yes
# 4   4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# 0  0.976473  Sometimes  Public_Transportation  Overweight_Level_II
# 1  1.000000         no             Automobile        Normal_Weight
# 2  1.673584         no  Public_Transportation  Insufficient_Weight
# 3  0.780199  Sometimes  Public_Transportation     Obesity_Type_III
# 4  0.931721  Sometimes  Public_Transportation  Overweight_Level_II

# %% [markdown]
# *Data description:*
#
# | Abbreviation   | Full Form                                 |
# |:---------------|:------------------------------------------|
# | FAVC           | Frequent consumption of high caloric food |
# | FCVC           | Frequency of consumption of vegetables    |
# | NCP            | Number of main meals                      |
# | CAEC           | Consumption of food between meals         |
# | CH20           | Consumption of water daily                |
# | CALC           | Consumption of alcohol                    |
# | SCC            | Calories consumption monitoring           |
# | FAF            | Physical activity frequency               |
# | TUE            | Time using technology devices             |
# | MTRANS         | Transportation used                       |
# | NObeyesdad     | Body mass index                           |

# %% [markdown]
# ## **DATA PREPARATION**

# %% [markdown]
# ### **DATA CLEANING**

# %% [markdown]
# #### > CHECK FOR NULL VALUES

# %%
if data.isnull().any().any():
    print("There are null values in the DataFrame.")
else:
    print("There are no null values in the DataFrame.")
# Out:
# There are no null values in the DataFrame.

# %% [markdown]
# #### > DROP REDUNDANT AND DUPLICATE FEATURES

# %%
data.drop(columns=['id'], axis=1,  inplace=True)

data.drop_duplicates()
# Out:
#        Gender        Age    Height      Weight family_history_with_overweight  \
# 0        Male  24.443011  1.699998   81.669950                            yes
# 1      Female  18.000000  1.560000   57.000000                            yes
# 2      Female  18.000000  1.711460   50.165754                            yes
# 3      Female  20.952737  1.710730  131.274851                            yes
# 4        Male  31.641081  1.914186   93.798055                            yes
# ...       ...        ...       ...         ...                            ...
# 20753    Male  25.137087  1.766626  114.187096                            yes
# 20754    Male  18.000000  1.710000   50.000000                             no
# 20755    Male  20.101026  1.819557  105.580491                            yes
# 20756    Male  33.852953  1.700000   83.520113                            yes
# 20757    Male  26.680376  1.816547  118.134898                            yes
#
#       FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0      yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1      yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2      yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3      yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4      yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
# ...    ...       ...       ...         ...   ...       ...  ..       ...
# 20753  yes  2.919584  3.000000   Sometimes    no  2.151809  no  1.330519
# 20754  yes  3.000000  4.000000  Frequently    no  1.000000  no  2.000000
# 20755  yes  2.407817  3.000000   Sometimes    no  2.000000  no  1.158040
# 20756  yes  2.671238  1.971472   Sometimes    no  2.144838  no  0.000000
# 20757  yes  3.000000  3.000000   Sometimes    no  2.003563  no  0.684487
#
#             TUE       CALC                 MTRANS           NObeyesdad
# 0      0.976473  Sometimes  Public_Transportation  Overweight_Level_II
# 1      1.000000         no             Automobile        Normal_Weight
# 2      1.673584         no  Public_Transportation  Insufficient_Weight
# 3      0.780199  Sometimes  Public_Transportation     Obesity_Type_III
# 4      0.931721  Sometimes  Public_Transportation  Overweight_Level_II
# ...         ...        ...                    ...                  ...
# 20753  0.196680  Sometimes  Public_Transportation      Obesity_Type_II
# 20754  1.000000  Sometimes  Public_Transportation  Insufficient_Weight
# 20755  1.198439         no  Public_Transportation      Obesity_Type_II
# 20756  0.973834         no             Automobile  Overweight_Level_II
# 20757  0.713823  Sometimes  Public_Transportation      Obesity_Type_II
#
# [20758 rows x 17 columns]

# %% [markdown]
# #### > CREATE A CSV FILE FOR CLEANED DATASET

# %%
filepath = Path('data/cleaned.csv')
filepath.parent.mkdir(parents=True, exist_ok=True)  
data.to_csv(filepath)

# %% [markdown]
# ### **FEATURES EDITION**

# %% [markdown]
# #### > CLASSIFY GROUP AGE

# %%
# Classify Group Age
age = data['Age']
def age2group(age):
    if age < 20:
        age = 'Under 20'
    elif age >= 50:
        age = 'Above 50'
    else:
        lowerbound = int(age / 10) * 10
        upperbound = (int(age / 10) + 1) * 10 - 1
        age = str(lowerbound) + '-' + str(upperbound)
    return age
data['Age'] = age.apply(age2group)

# %% [markdown]
# #### > ROUND VALUES

# %%
#Round values of each column to the appropriate decimal places
data['FCVC'] = data['FCVC'].round(1)
data['NCP'] = data['NCP'].round(1)
data['FAF'] = data['FAF'].round(2)
data['Height'] = data['Height'].round(2)
data['Weight'] = data["Weight"].round(1)
data['TUE'] = data['TUE'].round(2)
data['CH2O'] = data['CH2O'].round(2)

#Abbreviate features
data.rename(columns={'family_history_with_overweight': 'FHWO'}, inplace=True)

#Print dataset
data
# Out:
#        Gender       Age  Height  Weight FHWO FAVC  FCVC  NCP        CAEC  \
# 0        Male     20-29    1.70    81.7  yes  yes   2.0  3.0   Sometimes
# 1      Female  Under 20    1.56    57.0  yes  yes   2.0  3.0  Frequently
# 2      Female  Under 20    1.71    50.2  yes  yes   1.9  1.4   Sometimes
# 3      Female     20-29    1.71   131.3  yes  yes   3.0  3.0   Sometimes
# 4        Male     30-39    1.91    93.8  yes  yes   2.7  2.0   Sometimes
# ...       ...       ...     ...     ...  ...  ...   ...  ...         ...
# 20753    Male     20-29    1.77   114.2  yes  yes   2.9  3.0   Sometimes
# 20754    Male  Under 20    1.71    50.0   no  yes   3.0  4.0  Frequently
# 20755    Male     20-29    1.82   105.6  yes  yes   2.4  3.0   Sometimes
# 20756    Male     30-39    1.70    83.5  yes  yes   2.7  2.0   Sometimes
# 20757    Male     20-29    1.82   118.1  yes  yes   3.0  3.0   Sometimes
#
#       SMOKE  CH2O SCC   FAF   TUE       CALC                 MTRANS  \
# 0        no  2.76  no  0.00  0.98  Sometimes  Public_Transportation
# 1        no  2.00  no  1.00  1.00         no             Automobile
# 2        no  1.91  no  0.87  1.67         no  Public_Transportation
# 3        no  1.67  no  1.47  0.78  Sometimes  Public_Transportation
# 4        no  1.98  no  1.97  0.93  Sometimes  Public_Transportation
# ...     ...   ...  ..   ...   ...        ...                    ...
# 20753    no  2.15  no  1.33  0.20  Sometimes  Public_Transportation
# 20754    no  1.00  no  2.00  1.00  Sometimes  Public_Transportation
# 20755    no  2.00  no  1.16  1.20         no  Public_Transportation
# 20756    no  2.14  no  0.00  0.97         no             Automobile
# 20757    no  2.00  no  0.68  0.71  Sometimes  Public_Transportation
#
#                 NObeyesdad
# 0      Overweight_Level_II
# 1            Normal_Weight
# 2      Insufficient_Weight
# 3         Obesity_Type_III
# 4      Overweight_Level_II
# ...                    ...
# 20753      Obesity_Type_II
# 20754  Insufficient_Weight
# 20755      Obesity_Type_II
# 20756  Overweight_Level_II
# 20757      Obesity_Type_II
#
# [20758 rows x 17 columns]

# %% [markdown]
# #### > ADDING AND CALCULATING BMI
# Here we add a new feature 'BMI', which is calculated as 'Weight' / ('Height' ^ 2).

# %%
# Calculating Body Mass Index (BMI) + round to 2 decimal numbers
data['BMI'] = (data['Weight']/((data['Height'])**2)).round(2)

# %% [markdown]
# #### > REORDERING COLUMNS

# %%
data.columns[:]
data = data[['Gender', 'Age', 'Height', 'Weight', 'BMI', 'FHWO', 'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'MTRANS', 'NObeyesdad']]
data
# Out:
#        Gender       Age  Height  Weight    BMI FHWO FAVC  FCVC  NCP  \
# 0        Male     20-29    1.70    81.7  28.27  yes  yes   2.0  3.0
# 1      Female  Under 20    1.56    57.0  23.42  yes  yes   2.0  3.0
# 2      Female  Under 20    1.71    50.2  17.17  yes  yes   1.9  1.4
# 3      Female     20-29    1.71   131.3  44.90  yes  yes   3.0  3.0
# 4        Male     30-39    1.91    93.8  25.71  yes  yes   2.7  2.0
# ...       ...       ...     ...     ...    ...  ...  ...   ...  ...
# 20753    Male     20-29    1.77   114.2  36.45  yes  yes   2.9  3.0
# 20754    Male  Under 20    1.71    50.0  17.10   no  yes   3.0  4.0
# 20755    Male     20-29    1.82   105.6  31.88  yes  yes   2.4  3.0
# 20756    Male     30-39    1.70    83.5  28.89  yes  yes   2.7  2.0
# 20757    Male     20-29    1.82   118.1  35.65  yes  yes   3.0  3.0
#
#              CAEC SMOKE  CH2O SCC   FAF   TUE       CALC  \
# 0       Sometimes    no  2.76  no  0.00  0.98  Sometimes
# 1      Frequently    no  2.00  no  1.00  1.00         no
# 2       Sometimes    no  1.91  no  0.87  1.67         no
# 3       Sometimes    no  1.67  no  1.47  0.78  Sometimes
# 4       Sometimes    no  1.98  no  1.97  0.93  Sometimes
# ...           ...   ...   ...  ..   ...   ...        ...
# 20753   Sometimes    no  2.15  no  1.33  0.20  Sometimes
# 20754  Frequently    no  1.00  no  2.00  1.00  Sometimes
# 20755   Sometimes    no  2.00  no  1.16  1.20         no
# 20756   Sometimes    no  2.14  no  0.00  0.97         no
# 20757   Sometimes    no  2.00  no  0.68  0.71  Sometimes
#
#                       MTRANS           NObeyesdad
# 0      Public_Transportation  Overweight_Level_II
# 1                 Automobile        Normal_Weight
# 2      Public_Transportation  Insufficient_Weight
# 3      Public_Transportation     Obesity_Type_III
# 4      Public_Transportation  Overweight_Level_II
# ...                      ...                  ...
# 20753  Public_Transportation      Obesity_Type_II
# 20754  Public_Transportation  Insufficient_Weight
# 20755  Public_Transportation      Obesity_Type_II
# 20756             Automobile  Overweight_Level_II
# 20757  Public_Transportation      Obesity_Type_II
#
# [20758 rows x 18 columns]

# %% [markdown]
# #### > CREATE A CSV FILE FOR EDITED DATASET

# %%
newfile = Path('data/edited-train-set.csv')
newfile.parent.mkdir(parents=True, exist_ok=True)  
data.to_csv(newfile)
